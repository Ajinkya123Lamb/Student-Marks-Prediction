# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dic={
    "Hours_Studied":[2,4,6,8,10],
    "Attendance":[60,70,80,90,100],
    "Final_Marks":[45,55,65,78,88]
}

bf=pd.DataFrame(dic)
bf
# Out:
#    Hours_Studied  Attendance  Final_Marks
# 0              2          60           45
# 1              4          70           55
# 2              6          80           65
# 3              8          90           78
# 4             10         100           88

# %%
bf.to_csv("student_data.csv",index=False)
print("csv file saved")
# Out:
# csv file saved

# %%
from google.colab import files
files.download("student_data.csv")

# %%
df=pd.read_csv("student_data.csv")
df
# Out:
#    Hours_Studied  Attendance  Final_Marks
# 0              2          60           45
# 1              4          70           55
# 2              6          80           65
# 3              8          90           78
# 4             10         100           88

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hours_Studied  5 non-null      int64
#  1   Attendance     5 non-null      int64
#  2   Final_Marks    5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes
#        Hours_Studied  Attendance  Final_Marks
# count       5.000000    5.000000     5.000000
# mean        6.000000   80.000000    66.200000
# std         3.162278   15.811388    17.253985
# min         2.000000   60.000000    45.000000
# 25%         4.000000   70.000000    55.000000
# 50%         6.000000   80.000000    65.000000
# 75%         8.000000   90.000000    78.000000
# max        10.000000  100.000000    88.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Hours_Studied"], df["Final_Marks"])
plt.xlabel("Hours Studied")
plt.ylabel("Final Marks")
plt.title("Study Hours vs Marks")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

X = df[["Hours_Studied"]]
y = df["Final_Marks"]

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.predict([[7]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.65])

# %%
model.predict([[15]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([115.25])
